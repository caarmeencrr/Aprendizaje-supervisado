# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios) #barajamos para q no esten ordenaos

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Master' 'Grado' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Master'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Doctorado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Master' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Doctorado' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Doctorado' 'Doctorado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS para medir su frecuencia
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
#con variables cualitatias, la parte previa exploratoria de datos es muy importante
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
